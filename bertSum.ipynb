# %% [markdown]
# <a href="https://colab.research.google.com/github/prakharyadav-9/sentiment-analysis/blob/bert-model/bertSum.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import json
import matplotlib.pyplot as plt

# %%
from os.path import exists

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
#!pip install bert-extractive-summarizer

# %%
path = '/content/drive/MyDrive/BITS/SEM-II/RP/Research Practice/Task1_dev/train/'#'/content/drive/MyDrive/Research Practice/Task1_dev/train/'
fileName = 'PLOS_train.jsonl'

# %%
fullPath = path+fileName
print(fullPath)

# %%
print(exists(fullPath))
# Out:
# True

# %%
with open(fullPath) as f:
    dataList = [json.loads(line) for line in f]

df = pd.DataFrame()
for data in dataList:
  #print(len(data))
  df_dictionary = pd.DataFrame([data])
  df = pd.concat([df, df_dictionary], ignore_index=True)
  # for x in data:
  #   print(x,data[x])
  #break

# %%
# Library to implement BERT
from summarizer import Summarizer

# %%
len(dataList)
# Out:
# 24773

# %%
model=Summarizer()

# %%
df['bert_summary']=0

# %%
for i in range(len(df)):
  print(i)
  sent=df['article'][i].lower()
  result= model(sent,num_sentences=10,min_length=6)
  df['bert_summary'][i]=result

# %%
#write code to save df to csv
